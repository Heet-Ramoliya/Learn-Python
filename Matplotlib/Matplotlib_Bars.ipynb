# %% [markdown]
# ## What is a Bar Plot in Matplotlib?
#
# A bar plot (or bar chart) in Matplotlib is used to represent categorical data with rectangular bars. Each bar's length or height corresponds to the value of the data it represents. Bar plots are useful for:
#
# - Comparing quantities across different categories.
# - Visualizing frequency or count data.
# - Displaying aggregated data like means or sums for discrete groups.
# - Highlighting differences between groups in a clear, intuitive way.
#
# Matplotlib's `plt.bar()` function is used to create vertical bar plots, while `plt.barh()` creates horizontal bar plots.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()
